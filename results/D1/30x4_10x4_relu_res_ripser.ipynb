# %%
import sys
sys.path.append('/project2/alvinjin_1630/results')

from Trainer import Trainer
# Out:
# /project2/alvinjin_1630

# %%
import torch, jax
print("PyTorch sees:", torch.cuda.device_count(), "GPUs,", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "none")
print("JAX sees:", jax.devices())
# Out:
# PyTorch sees: 0 GPUs, none
# JAX sees: [CpuDevice(id=0)]

# %%
trainer = Trainer(
    dataset='D1',
    hidden_dims=[30] * 4 + [10] * 4,
    act_fn=jax.nn.relu,
    study_name='30x4_10x4_relu_res',
    residual=True
)

trainer.run_ripser(model_ids=range(18, 24))
# Out:
# Model_ids: range(18, 24)
# Running ripser:   0%|          | 0/6 [00:00<?, ?it/s]/home1/adshaw/.local/lib/python3.13/site-packages/equinox/nn/_normalisation.py:92: UserWarning: LayerNorm(elementwise_affine=...) is deprecated in favour of LayerNorm(use_weight=...) and LayerNorm(use_bias=...)
#   warnings.warn(
# Running ripser:  17%|█▋        | 1/6 [00:40<03:20, 40.15s/it]/home1/adshaw/.local/lib/python3.13/site-packages/equinox/nn/_normalisation.py:92: UserWarning: LayerNorm(elementwise_affine=...) is deprecated in favour of LayerNorm(use_weight=...) and LayerNorm(use_bias=...)
#   warnings.warn(
# Running ripser:  33%|███▎      | 2/6 [01:20<02:40, 40.21s/it]/home1/adshaw/.local/lib/python3.13/site-packages/equinox/nn/_normalisation.py:92: UserWarning: LayerNorm(elementwise_affine=...) is deprecated in favour of LayerNorm(use_weight=...) and LayerNorm(use_bias=...)
#   warnings.warn(
# Running ripser:  50%|█████     | 3/6 [02:00<02:00, 40.18s/it]/home1/adshaw/.local/lib/python3.13/site-packages/equinox/nn/_normalisation.py:92: UserWarning: LayerNorm(elementwise_affine=...) is deprecated in favour of LayerNorm(use_weight=...) and LayerNorm(use_bias=...)
#   warnings.warn(
# Running ripser:  67%|██████▋   | 4/6 [02:40<01:20, 40.24s/it]/home1/adshaw/.local/lib/python3.13/site-packages/equinox/nn/_normalisation.py:92: UserWarning: LayerNorm(elementwise_affine=...) is deprecated in favour of LayerNorm(use_weight=...) and LayerNorm(use_bias=...)
#   warnings.warn(
# Running ripser:  83%|████████▎ | 5/6 [03:21<00:40, 40.23s/it]/home1/adshaw/.local/lib/python3.13/site-packages/equinox/nn/_normalisation.py:92: UserWarning: LayerNorm(elementwise_affine=...) is deprecated in favour of LayerNorm(use_weight=...) and LayerNorm(use_bias=...)
#   warnings.warn(
# Running ripser: 100%|██████████| 6/6 [04:01<00:00, 40.21s/it]

# %%
trainer.graph_betti_numbers()
