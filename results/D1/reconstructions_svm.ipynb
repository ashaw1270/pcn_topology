# %%
import sys
sys.path.append('/project2/alvinjin_1630/results')

from Trainer import Trainer
# Out:
# /project2/alvinjin_1630

# %%
data = Trainer.get_bootstrap_data(data_filename='all_8_layer_models_all_stats_mean_alpha0.05', studies=['30x4_.*x4', '30x8'])
Trainer.plot_mrd_tss(data, print_all=True, title=r'MRD vs. TSS, All Models', save=False, filename='all_models')

data = Trainer.get_bootstrap_data(data_filename='all_8_layer_models_all_stats_mean_alpha0.05')
Trainer.plot_mrd_tss(data, print_all=True, title=r'MRD vs. TSS, All Models', save=False, filename='all_models')
# Out:
# ['30x4_10x4_relu', '30x4_10x4_tanh', '30x4_12x4_relu', '30x4_18x4_relu', '30x4_18x4_tanh', '30x4_18x4_leaky', '30x4_24x4_relu', '30x4_24x4_tanh', '30x4_24x4_leaky', '30x8_relu', '30x8_tanh', '30x8_leaky']
# Num models: 12
#
# 30x4_10x4_relu: 0.730, 0.122
# 30x4_10x4_tanh: 0.636, 0.082
# 30x4_12x4_relu: 0.710, 0.067
# 30x4_18x4_relu: 0.618, 0.055
# 30x4_18x4_tanh: 0.415, 0.052
# 30x4_18x4_leaky: 0.493, 0.047
# 30x4_24x4_relu: 0.565, 0.041
# 30x4_24x4_tanh: 0.345, 0.044
# 30x4_24x4_leaky: 0.447, 0.050
# 30x8_relu: 0.389, 0.044
# 30x8_tanh: 0.315, 0.027
# 30x8_leaky: 0.338, 0.024
#
# Pearson correlation coefficient: 0.7986033422025544
# P-value: 0.0018402906132436263
#
# Spearman correlation: 0.8461538461538463
# P-value: 0.000521133700481005
# ...
