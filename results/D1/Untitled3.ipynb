# %%
import sys
sys.path.append('/project2/alvinjin_1630/results')

from Trainer import Trainer
# Out:
# /project2/alvinjin_1630

# %%
import torch, jax
print("PyTorch sees:", torch.cuda.device_count(), "GPUs,", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "none")
print("JAX sees:", jax.devices())
# Out:
# PyTorch sees: 0 GPUs, none
# JAX sees: [CpuDevice(id=0)]

# %%
trainer1 = Trainer(
    dataset='D1',
    hidden_dims=[30] * 8,
    act_fn=jax.nn.tanh,
    study_name='30x8_tanh',
    residual=False
)

trainer2 = Trainer(
    dataset='D1',
    hidden_dims=[24] * 8,
    act_fn=jax.nn.tanh,
    study_name='24x8_tanh',
    residual=False
)

# %%
# Trainer.compare_graphs(
#     trainers=[trainer1, trainer2, trainer3, trainer4, trainer5, trainer6],
#     dir_names=['ripser_only_0_k14'] * 6,
#     eta=2.5,
#     k=14,
#     dim=0,
#     title=r'30x4 + $d$x4 ReLU',
#     legend=[r'$d=30$', r'$d=24$', r'$d=18$', r'$d=12$', r'$d=10$', '24x8']
# )

Trainer.compare_graphs(
    trainers=[trainerr, trainert],
    dir_names=['ripser_only_0_k14'] * 2,
    eta=2.5,
    k=14,
    dim=0,
    title='15x4_30x4, ReLU vs. Tanh',
    legend=['ReLU', 'Tanh']
)
