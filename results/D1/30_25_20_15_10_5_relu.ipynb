# %%
import sys
sys.path.append('/project2/alvinjin_1630/results')

from Trainer import Trainer
# Out:
# /project2/alvinjin_1630

# %%
import torch, jax
print("PyTorch sees:", torch.cuda.device_count(), "GPUs,", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "none")
print("JAX sees:", jax.devices())
# Out:
# PyTorch sees: 0 GPUs, none
# JAX sees: [CpuDevice(id=0)]

# %%
Trainer.start_optuna_dashboard()

# %%
trainer = Trainer(
    dataset='D1',
    hidden_dims=[30, 25, 20, 15, 10, 5],
    act_fn=jax.nn.relu,
    study_name='30_25_20_15_10_5_relu',
    residual=False
)

# trainer.run_optuna(
#     num_models=3,
#     T_func=lambda trial: trial.suggest_int('T', 21, 35, step=7),
#     start_lr_w_func=lambda trial: trial.suggest_float('lr_w', 5e-7, 1e-3, log=True),
#     start_lr_h_func=lambda trial: trial.suggest_float('lr_h', 5e-5, 2e-1, log=True),
#     trans_mult_func=lambda trial: trial.suggest_float('trans_mult', 3, 20),
#     decay_rate_func=lambda trial: trial.suggest_float('decay_rate', 0.85, 0.99)
# )

# trainer.train_all_models(
#     T=28,
#     start_lr_w=1.197e-4,
#     start_lr_h=1.751e-2,
#     trans_mult=9.213,
#     decay_rate=0.8911,
#     model_ids=range(2, 35)
# )

trainer.graph_betti_numbers(save=True)
