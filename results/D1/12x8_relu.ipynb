# %%
import sys
sys.path.append('/project2/alvinjin_1630/results')

from Trainer import Trainer
# Out:
# /project2/alvinjin_1630

# %%
import torch, jax
print("PyTorch sees:", torch.cuda.device_count(), "GPUs,", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "none")
print("JAX sees:", jax.devices())
# Out:
# PyTorch sees: 1 GPUs, NVIDIA A100-PCIE-40GB
# JAX sees: [CudaDevice(id=0)]

# %%
Trainer.start_optuna_dashboard()
# Out:
# Starting Optuna dashboard on http://localhost:8080
# Bottle v0.13.4 server starting up (using WSGIRefServer())...
# Listening on http://0.0.0.0:8080/
# Hit Ctrl-C to quit.
# Run the following command in your local terminal on YOUR MACHINE, not in the cluster:
# ssh -L 8080:a01-01.hpc.usc.edu:8080 {YOUR USERNAME}@discovery.usc.edu
# Once you enter the cluster from your terminal, navigate to http://localhost:8080 in a web browser
# 10.125.0.217 - - [05/Oct/2025 09:37:53] "GET / HTTP/1.1" 302 0
# 10.125.0.217 - - [05/Oct/2025 09:37:53] "GET /static/bundle.js HTTP/1.1" 200 4140378
# 10.125.0.217 - - [05/Oct/2025 09:37:54] "GET /api/studies HTTP/1.1" 200 3190
# 10.125.0.217 - - [05/Oct/2025 09:37:55] "GET /api/studies/29/param_importances?evaluator=ped_anova HTTP/1.1" 200 27
# 10.125.0.217 - - [05/Oct/2025 09:37:55] "GET /api/studies/29?after=0 HTTP/1.1" 200 2777
# 10.125.0.217 - - [05/Oct/2025 09:37:55] "GET /api/meta HTTP/1.1" 200 64
# 10.125.0.217 - - [05/Oct/2025 09:37:58] "GET /api/studies/29?after=0 HTTP/1.1" 200 2777
# 10.125.0.217 - - [05/Oct/2025 09:38:00] "GET /api/studies/29?after=0 HTTP/1.1" 200 2777
# 10.125.0.217 - - [05/Oct/2025 09:38:03] "GET /api/studies/29?after=0 HTTP/1.1" 200 2777
# 10.125.0.217 - - [05/Oct/2025 09:38:06] "GET /api/studies/29?after=0 HTTP/1.1" 200 2777
# 10.125.0.217 - - [05/Oct/2025 09:38:09] "GET /api/studies/29?after=0 HTTP/1.1" 200 2777
# 10.125.0.217 - - [05/Oct/2025 09:38:12] "GET /api/studies/29?after=0 HTTP/1.1" 200 2777
# 10.125.0.217 - - [05/Oct/2025 09:38:15] "GET /api/studies/29?after=0 HTTP/1.1" 200 2777
# 10.125.0.217 - - [05/Oct/2025 09:38:18] "GET /api/studies/29?after=0 HTTP/1.1" 200 2777
# 10.125.0.217 - - [05/Oct/2025 09:38:21] "GET /api/studies/29?after=0 HTTP/1.1" 200 2777
# 10.125.0.217 - - [05/Oct/2025 09:38:24] "GET /api/studies/29?after=0 HTTP/1.1" 200 2777
# 10.125.0.217 - - [05/Oct/2025 09:38:27] "GET /api/studies/29?after=0 HTTP/1.1" 200 2777
# 10.125.0.217 - - [05/Oct/2025 09:38:30] "GET /api/studies/29?after=0 HTTP/1.1" 200 2777

# %%
trainer = Trainer(
    dataset='D1',
    hidden_dims=[12] * 8,
    act_fn=jax.nn.relu,
    study_name='12x8_relu',
    residual=False
)

trainer.run_optuna(
    num_models=3,
    T_func=lambda trial: 30,
    start_lr_w_func=lambda trial: trial.suggest_float('lr_w', 1e-6, 8e-3, log=True),
    start_lr_h_func=lambda trial: trial.suggest_float('lr_h', 1e-4, 1e-1, log=True),
    trans_mult_func=lambda trial: trial.suggest_float('trans_mult', 3, 20),
    decay_rate_func=lambda trial: trial.suggest_float('decay_rate', 0.85, 0.99),
    add_trials=[{'lr_w': 2.163e-4, 'lr_h': 6.757e-2, 'trans_mult': 17.98, 'decay_rate': 0.9371}]
)
# Out:
# [I 2025-10-05 09:37:37,374] A new study created in RDB with name: D1_12x8_relu
# /home1/adshaw/.local/lib/python3.13/site-packages/equinox/nn/_normalisation.py:92: UserWarning: LayerNorm(elementwise_affine=...) is deprecated in favour of LayerNorm(use_weight=...) and LayerNorm(use_bias=...)
#   warnings.warn(
