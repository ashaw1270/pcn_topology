# %%
import sys
sys.path.append('/project2/alvinjin_1630/results')

from Trainer import Trainer
# Out:
# /project2/alvinjin_1630

# %%
import torch, jax
print("PyTorch sees:", torch.cuda.device_count(), "GPUs,", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "none")
print("JAX sees:", jax.devices())
# Out:
# PyTorch sees: 1 GPUs, NVIDIA A100 80GB PCIe
# JAX sees: [CudaDevice(id=0)]

# %%
Trainer.start_optuna_dashboard()

# %%
trainer = Trainer(
    dataset='D1',
    hidden_dims=[15] * 4 + [30] * 4,
    act_fn=jax.nn.relu,
    study_name='15x4_30x4_relu',
    residual=False
)

# trainer.run_optuna(
#     num_models=3,
#     T_func=lambda trial: 30,
#     start_lr_w_func=lambda trial: trial.suggest_float('lr_w', 5e-7, 1e-3, log=True),
#     start_lr_h_func=lambda trial: trial.suggest_float('lr_h', 2e-3, 2e-1, log=True),
#     trans_mult_func=lambda trial: trial.suggest_float('trans_mult', 3, 20),
#     decay_rate_func=lambda trial: trial.suggest_float('decay_rate', 0.85, 0.99)
# )

trainer.train_all_models(
    T=30,
    start_lr_w=1.824e-4,
    start_lr_h=3.713e-2,
    trans_mult=17.32,
    decay_rate=0.8974,
    model_ids=range(21, 40)
)
# Out:
# /home1/adshaw/.local/lib/python3.13/site-packages/equinox/nn/_normalisation.py:92: UserWarning: LayerNorm(elementwise_affine=...) is deprecated in favour of LayerNorm(use_weight=...) and LayerNorm(use_bias=...)
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 18
#       1 trainer = Trainer(
#       2     dataset='D1',
#       3     hidden_dims=[15] * 4 + [30] * 4,
#    (...)      6     residual=False
#       7 )
#       9 # trainer.run_optuna(
#      10 #     num_models=3,
#      11 #     T_func=lambda trial: 30,
#    (...)     15 #     decay_rate_func=lambda trial: trial.suggest_float('decay_rate', 0.85, 0.99)
#      16 # )
# ---> 18 trainer.train_all_models(
#      19     T=30,
#      20     start_lr_w=1.824e-4,
#      21     start_lr_h=3.713e-2,
#      22     trans_mult=17.32,
#      23     decay_rate=0.8974,
#      24     model_ids=range(21, 40)
#      25 )
#
# File /project2/alvinjin_1630/results/Trainer.py:448, in Trainer.train_all_models(self, T, start_lr_w, start_lr_h, trans_mult, decay_rate, model_ids, early_stopping)
#     445     model_ids = range(self.num_models)
#     447 for i in model_ids:
# --> 448     self.train_model(
#     449         model_id=i,
#     450         T=T,
#     451         start_lr_w=start_lr_w,
#     452         start_lr_h=start_lr_h,
#     453         trans_mult=trans_mult,
#     454         decay_rate=decay_rate,
#     455         early_stopping=early_stopping
#     456     )
#
# File /project2/alvinjin_1630/results/Trainer.py:416, in Trainer.train_model(self, model_id, T, start_lr_w, start_lr_h, trans_mult, decay_rate, early_stopping)
#     414 for epoch in range(self.num_epochs):
#     415     train_loader = self.get_epoch_dataloader(model_id, epoch)
# --> 416     train(train_loader, T=T, model=model, optim_w=optim_w, optim_h=optim_h)
#     418     test_acc, _ = eval(self.test_loader, model=model)
#     419     if test_acc > best_test_acc:
#
# File /project2/alvinjin_1630/results/Trainer.py:257, in train(dl, T, model, optim_w, optim_h)
#     255 x_jax = jnp.asarray(x_flat)
#     256 y_jax = jnp.asarray(y)
# --> 257 train_on_batch(T, x_jax, jax.nn.one_hot(y_jax, model.output_dim.get()), model=model, optim_w=optim_w, optim_h=optim_h)
#
# File ~/.local/lib/python3.13/site-packages/pcx/functional/_transform.py:183, in _BaseTransform.__call__(self, _is_root, *args, **kwargs)
#     177 # This is the key part: the updated values are injected back into the original parameters in 'kwargs'. 'kwargs'
#     178 # is still the original structure as it hasn't undergone any transformation (which happens only inside '_t').
#     179 # The update values are obtained by calling 'extract', which is done automatically by the wrapped 'fn'.
#     180 # If 'tree_extract' is called before returning '_kwargs', a list of value was returned, so we tell 'tree_inject'
#     181 # to handle it correctly.
#     182 if isinstance(kwargs, dict):
# --> 183     tree_inject(kwargs, params=_kwargs, is_pytree=True)
#     184 else:
#     185     tree_inject(kwargs, values=_kwargs, is_pytree=True)
#
# File ~/.local/lib/python3.13/site-packages/pcx/core/_tree.py:222, in tree_inject(pydag, params, values, inject_fn, filter_fn, is_pytree, strict)
#     219     else:
#     220         return False
# --> 222 jtu.tree_leaves(pydag, is_leaf=_inject_param)
#     224 if strict is True:
#     225     # This is to assert the user didn't mess up with the pytree structure.
#     226     try:
#
# File ~/.local/lib/python3.13/site-packages/jax/_src/tree_util.py:92, in tree_leaves(tree, is_leaf)
#      87 @export
#      88 def tree_leaves(tree: Any,
#      89                 is_leaf: Callable[[Any], bool] | None = None
#      90                 ) -> list[Leaf]:
#      91   """Alias of :func:`jax.tree.leaves`."""
# ---> 92   return default_registry.flatten(tree, is_leaf)[0]
#
# File ~/.local/lib/python3.13/site-packages/pcx/core/_tree.py:213, in tree_inject.<locals>._inject_param(x)
#     210 # We use jtu.tree_leaves to apply inject_fn to the dynamically identified leaves of the pytree.
#     211 _values_it = iter(values)
# --> 213 def _inject_param(x: Any):
#     214     if isinstance(x, BaseParam):
#     215         if filter_fn(x):
#
# KeyboardInterrupt:
