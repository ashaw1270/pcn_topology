# %%
import sys
sys.path.append('/project2/alvinjin_1630/results')

from Trainer import Trainer
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, jax
print("PyTorch sees:", torch.cuda.device_count(), "GPUs,", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "none")
print("JAX sees:", jax.devices())

# %%
trainer = Trainer(
    dataset='D1',
    hidden_dims=[50]*9,
    act_fn=jax.nn.relu,
    study_name='50_times_9_relu'
)

# # trainer.run_optuna(
# #     num_models=3,
# #     T_func=lambda trial: trial.suggest_int('T', 20, 50, step=15),
# #     start_lr_w_func=lambda trial: trial.suggest_float('lr_w', 1e-5, 6e-4, log=True),
# #     start_lr_h_func=lambda trial: trial.suggest_float('lr_h', 1e-3, 8e-2, log=True),
# #     trans_mult_func=lambda trial: trial.suggest_float('trans_mult', 8, 20),
# #     decay_rate_func=lambda trial: trial.suggest_float('decay_rate', 0.9, 0.99)
# # )

# # trainer.train_all_models(
# #     T=35,
# #     start_lr_w=5.050e-5,
# #     start_lr_h=3.109e-3,
# #     trans_mult=9.332,
# #     decay_rate=0.9766,
# #     model_ids=range(15, 50)
# # )


# # import dill
# # with open(f'{trainer.root}/reduced_dl_25_percent.pkl', 'rb') as f:
# #     reduced_dl = dill.load(f)

# from torch.utils.data import DataLoader, ConcatDataset

# full_dataset = ConcatDataset([trainer.train_dataset, trainer.test_dataset])
# full_dl = DataLoader(full_dataset, batch_size=trainer.batch_size, shuffle=False, drop_last=True)

# trainer.run_ripser(
#     dl=full_dl,
#     dir_name='ripser_full_dataset_k5',
#     k=5,
#     maxdim=0,
#     thresh=3
# )

# # trainer.graph_betti_numbers(dir_name='ripser_25_percent_k14', etas=[2.5], maxdim=1)
