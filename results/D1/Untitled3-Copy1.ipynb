# %%
import sys
sys.path.append('/project2/alvinjin_1630/results')

from Trainer import Trainer
# Out:
# /project2/alvinjin_1630

# %%
import torch, jax
print("PyTorch sees:", torch.cuda.device_count(), "GPUs,", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "none")
print("JAX sees:", jax.devices())
# Out:
# PyTorch sees: 0 GPUs, none
# JAX sees: [CpuDevice(id=0)]

# %%
trainer1 = Trainer(
    dataset='D1',
    hidden_dims=[30] * 8,
    act_fn=jax.nn.relu,
    study_name='30x8_relu',
    residual=False
)

trainer2 = Trainer(
    dataset='D1',
    hidden_dims=[24] * 8,
    act_fn=jax.nn.relu,
    study_name='24x8_relu',
    residual=False
)

trainer3 = Trainer(
    dataset='D1',
    hidden_dims=[18] * 8,
    act_fn=jax.nn.relu,
    study_name='18x8_relu',
    residual=False
)

trainer4 = Trainer(
    dataset='D1',
    hidden_dims=[30] * 4 + [24] * 4,
    act_fn=jax.nn.relu,
    study_name='30x4_24x4_relu',
    residual=False
)

trainer5 = Trainer(
    dataset='D1',
    hidden_dims=[30] * 4 + [18] * 4,
    act_fn=jax.nn.relu,
    study_name='30x4_18x4_relu',
    residual=False
)

trainer6 = Trainer(
    dataset='D1',
    hidden_dims=[30] * 4 + [12] * 4,
    act_fn=jax.nn.relu,
    study_name='30x4_12x4_relu',
    residual=False
)

trainer7 = Trainer(
    dataset='D1',
    hidden_dims=[30] * 4 + [10] * 4,
    act_fn=jax.nn.relu,
    study_name='30x4_10x4_relu',
    residual=False
)

trainer8 = Trainer(
    dataset='D1',
    hidden_dims=[15] * 4 + [30] * 4,
    act_fn=jax.nn.relu,
    study_name='15x4_30x4_relu',
    residual=False
)

# %%
Trainer.compare_graphs(
    trainers=[trainer1, trainer2, trainer3, trainer4, trainer5, trainer6, trainer7, trainer8],
    title=r'All 8-Layer Models ReLU',
    save_data=True,
    filename='all_8_layer_relu'
)
