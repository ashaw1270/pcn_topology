# %%
import sys
sys.path.append('/project2/alvinjin_1630/results')

from Trainer import Trainer
# Out:
# /project2/alvinjin_1630

# %%
import torch, jax
print("PyTorch sees:", torch.cuda.device_count(), "GPUs,", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "none")
print("JAX sees:", jax.devices())
# Out:
# PyTorch sees: 1 GPUs, NVIDIA A100-PCIE-40GB
# JAX sees: [CudaDevice(id=0)]

# %%
Trainer.start_optuna_dashboard()
# Out:
# Starting Optuna dashboard on http://localhost:8080
# Bottle v0.13.4 server starting up (using WSGIRefServer())...
# Listening on http://0.0.0.0:8080/
# Hit Ctrl-C to quit.
# Run the following command in your local terminal on YOUR MACHINE, not in the cluster:
# ssh -L 8080:b01-01.hpc.usc.edu:8080 {YOUR USERNAME}@discovery.usc.edu
# Once you enter the cluster from your terminal, navigate to http://localhost:8080 in a web browser
# 10.125.0.217 - - [29/Sep/2025 12:33:20] "GET / HTTP/1.1" 302 0
# 10.125.0.217 - - [29/Sep/2025 12:33:20] "GET /static/bundle.js HTTP/1.1" 200 4140378
# 10.125.0.217 - - [29/Sep/2025 12:33:21] "GET /api/studies HTTP/1.1" 200 2705
# 10.125.0.217 - - [29/Sep/2025 12:33:43] "GET /api/studies HTTP/1.1" 200 2705
# 10.125.0.217 - - [29/Sep/2025 12:33:44] "GET /api/studies/24/param_importances?evaluator=ped_anova HTTP/1.1" 200 27
# 10.125.0.217 - - [29/Sep/2025 12:33:44] "GET /api/studies/24?after=0 HTTP/1.1" 200 7370
# 10.125.0.217 - - [29/Sep/2025 12:33:44] "GET /api/meta HTTP/1.1" 200 64
# 10.125.0.217 - - [29/Sep/2025 12:33:45] "GET /api/studies/24/param_importances?evaluator=ped_anova HTTP/1.1" 200 27
# 10.125.0.217 - - [29/Sep/2025 12:33:48] "GET /api/studies/24?after=3 HTTP/1.1" 200 2959
# 10.125.0.217 - - [29/Sep/2025 12:33:50] "GET /api/studies/24?after=3 HTTP/1.1" 200 2959
# 10.125.0.217 - - [29/Sep/2025 12:33:52] "GET /api/studies/24?after=3 HTTP/1.1" 200 2959
# 10.125.0.217 - - [29/Sep/2025 12:33:53] "GET /api/studies HTTP/1.1" 200 2705
# /home1/adshaw/.local/lib/python3.13/site-packages/optuna_dashboard/_importance.py:71: ExperimentalWarning: PedAnovaImportanceEvaluator is experimental (supported from v3.6.0). The interface can change in the future.
#   study, target=target, evaluator=PedAnovaImportanceEvaluator()
# /home1/adshaw/.local/lib/python3.13/site-packages/optuna/importance/_ped_anova/evaluator.py:148: UserWarning: PedAnovaImportanceEvaluator computes the importances of params to achieve low `target` values. If this is not what you want, please modify target, e.g., by multiplying the output by -1.
#   warnings.warn(
# 10.125.0.217 - - [29/Sep/2025 12:33:54] "GET /api/studies/19/param_importances?evaluator=ped_anova HTTP/1.1" 200 216
# 10.125.0.217 - - [29/Sep/2025 12:33:54] "GET /api/studies/19?after=0 HTTP/1.1" 200 76810
# 10.125.0.217 - - [29/Sep/2025 12:33:54] "GET /api/meta HTTP/1.1" 200 64
# 10.125.0.217 - - [29/Sep/2025 12:33:54] "GET /api/studies/19/param_importances?evaluator=ped_anova HTTP/1.1" 200 216
# 10.125.0.217 - - [29/Sep/2025 12:33:57] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:33:59] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:01] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:03] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:05] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:07] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:09] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:12] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:14] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:16] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:18] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:20] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:22] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:24] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:27] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:30] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:32] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:34] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:36] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:38] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:40] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:42] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:44] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:46] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:48] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:50] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857
# 10.125.0.217 - - [29/Sep/2025 12:34:52] "GET /api/studies/19?after=50 HTTP/1.1" 200 2857

# %%
trainer = Trainer(
    dataset='D1',
    hidden_dims=[30] * 4 + [12] * 4,
    act_fn=jax.nn.relu,
    study_name='30x4_12x4_relu',
    residual=False
)

trainer.run_optuna(
    num_models=3,
    T_func=lambda trial: 30,
    start_lr_w_func=lambda trial: trial.suggest_float('lr_w', 1e-6, 5e-3, log=True),
    start_lr_h_func=lambda trial: trial.suggest_float('lr_h', 1e-4, 1e-1, log=True),
    trans_mult_func=lambda trial: trial.suggest_float('trans_mult', 3, 20),
    decay_rate_func=lambda trial: trial.suggest_float('decay_rate', 0.85, 0.99),
    add_trials=[{'lr_w': 4.868e-4, 'lr_h': 4.218e-2, 'trans_mult': 11.96, 'decay_rate': 0.9328}]
)

# trainer.train_all_models(
#     T=30,
#     start_lr_w=4.868e-4,
#     start_lr_h=4.218e-2,
#     trans_mult=11.96,
#     decay_rate=0.9328,
#     model_ids=range(30, 35)
# )
