# %%
import sys
sys.path.append('/project2/alvinjin_1630/results')

from Trainer import Trainer
# Out:
# /project2/alvinjin_1630

# %%
import torch, jax
print("PyTorch sees:", torch.cuda.device_count(), "GPUs,", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "none")
print("JAX sees:", jax.devices())
# Out:
# PyTorch sees: 1 GPUs, NVIDIA A100 80GB PCIe
# JAX sees: [CudaDevice(id=0)]

# %%
trainer = Trainer(
    dataset='D1',
    hidden_dims=[10] * 4 + [30] * 4,
    act_fn=jax.nn.relu,
    study_name='10x4_30x4_relu',
    residual=False
)

# trainer.run_optuna(
#     num_models=3,
#     T_func=lambda trial: 30,
#     start_lr_w_func=lambda trial: trial.suggest_float('lr_w', 5e-7, 1e-3, log=True),
#     start_lr_h_func=lambda trial: trial.suggest_float('lr_h', 5e-3, 2e-1, log=True),
#     trans_mult_func=lambda trial: trial.suggest_float('trans_mult', 3, 20),
#     decay_rate_func=lambda trial: trial.suggest_float('decay_rate', 0.85, 0.99)
# )

trainer.train_all_models(
    T=30,
    start_lr_w=3.523e-4,
    start_lr_h=1.233e-2,
    trans_mult=11.82,
    decay_rate=0.9060
)
# Out:
# /home1/adshaw/.local/lib/python3.13/site-packages/equinox/nn/_normalisation.py:92: UserWarning: LayerNorm(elementwise_affine=...) is deprecated in favour of LayerNorm(use_weight=...) and LayerNorm(use_bias=...)
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 18
#       1 trainer = Trainer(
#       2     dataset='D1',
#       3     hidden_dims=[10] * 4 + [30] * 4,
#    (...)      6     residual=False
#       7 )
#       9 # trainer.run_optuna(
#      10 #     num_models=3,
#      11 #     T_func=lambda trial: 30,
#    (...)     15 #     decay_rate_func=lambda trial: trial.suggest_float('decay_rate', 0.85, 0.99)
#      16 # )
# ---> 18 trainer.train_all_models(
#      19     T=30,
#      20     start_lr_w=3.523e-4,
#      21     start_lr_h=1.233e-2,
#      22     trans_mult=11.82,
#      23     decay_rate=0.9060
#      24 )
#
# File /project2/alvinjin_1630/results/Trainer.py:443, in Trainer.train_all_models(self, T, start_lr_w, start_lr_h, trans_mult, decay_rate, model_ids, early_stopping)
#     440     model_ids = range(self.num_models)
#     442 for i in model_ids:
# --> 443     self.train_model(
#     444         model_id=i,
#     445         T=T,
#     446         start_lr_w=start_lr_w,
#     447         start_lr_h=start_lr_h,
#     448         trans_mult=trans_mult,
#     449         decay_rate=decay_rate,
#     450         early_stopping=early_stopping
#     451     )
#
# File /project2/alvinjin_1630/results/Trainer.py:411, in Trainer.train_model(self, model_id, T, start_lr_w, start_lr_h, trans_mult, decay_rate, early_stopping)
#     409 for epoch in range(self.num_epochs):
#     410     train_loader = self.get_epoch_dataloader(model_id, epoch)
# --> 411     train(train_loader, T=T, model=model, optim_w=optim_w, optim_h=optim_h)
#     413     test_acc, _ = eval(self.test_loader, model=model)
#     414     if test_acc > best_test_acc:
#
# File /project2/alvinjin_1630/results/Trainer.py:253, in train(dl, T, model, optim_w, optim_h)
#     251 x_jax = jnp.asarray(x_flat)
#     252 y_jax = jnp.asarray(y)
# --> 253 train_on_batch(T, x_jax, jax.nn.one_hot(y_jax, model.output_dim.get()), model=model, optim_w=optim_w, optim_h=optim_h)
#
# File ~/.local/lib/python3.13/site-packages/pcx/functional/_transform.py:175, in _BaseTransform.__call__(self, _is_root, *args, **kwargs)
#     173 if _is_root is True:
#     174     kwargs = tree_ref(kwargs)
# --> 175 _r, _kwargs = self._t(*args, **kwargs)
#     177 # This is the key part: the updated values are injected back into the original parameters in 'kwargs'. 'kwargs'
#     178 # is still the original structure as it hasn't undergone any transformation (which happens only inside '_t').
#     179 # The update values are obtained by calling 'extract', which is done automatically by the wrapped 'fn'.
#     180 # If 'tree_extract' is called before returning '_kwargs', a list of value was returned, so we tell 'tree_inject'
#     181 # to handle it correctly.
#     182 if isinstance(kwargs, dict):
#
# File ~/.local/lib/python3.13/site-packages/pcx/functional/_transform.py:260, in Jit._t(self, *args, **kwargs)
#     259 def _t(self, *args, **kwargs):
# --> 260     _r, kwargs = self.wrap_fn(*args, **kwargs)
#     262     return _r, kwargs
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.13/site-packages/jax/_src/pjit.py:339, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     334 if config.no_tracing.value:
#     335   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     336                      "`jit`, but 'no_tracing' is set")
#     338 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, executable,
# --> 339  pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     341 maybe_fastpath_data = _get_fastpath_data(
#     342     executable, out_tree, args_flat, out_flat, attrs_tracked, jaxpr.effects,
#     343     jaxpr.consts, jit_info.abstracted_axes,
#     344     pgle_profiler)
#     346 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/.local/lib/python3.13/site-packages/jax/_src/pjit.py:194, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     192   args_flat = map(core.full_lower, args_flat)
#     193   core.check_eval_args(args_flat)
# --> 194   out_flat, compiled, profiler = _pjit_call_impl_python(*args_flat, **p.params)
#     195 else:
#     196   out_flat = pjit_p.bind(*args_flat, **p.params)
#
# File ~/.local/lib/python3.13/site-packages/jax/_src/pjit.py:1659, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1647 compiler_options_kvs = compiler_options_kvs + tuple(pgle_compile_options.items())
#    1648 # Passing mutable PGLE profile here since it should be extracted by JAXPR to
#    1649 # initialize the fdo_profile compile option.
#    1650 compiled = _resolve_and_lower(
#    1651     args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1652     out_shardings=out_shardings, in_layouts=in_layouts,
#    1653     out_layouts=out_layouts, donated_invars=donated_invars,
#    1654     ctx_mesh=ctx_mesh, name=name, keep_unused=keep_unused,
#    1655     inline=inline, lowering_platforms=None,
#    1656     lowering_parameters=mlir.LoweringParameters(),
#    1657     pgle_profiler=pgle_profiler,
#    1658     compiler_options_kvs=compiler_options_kvs,
# -> 1659 ).compile()
#    1661 # This check is expensive so only do it if enable_checks is on.
#    1662 if compiled._auto_spmd_lowering and config.enable_checks.value:
#
# File ~/.local/lib/python3.13/site-packages/jax/_src/interpreters/pxla.py:2448, in MeshComputation.compile(self, compiler_options)
#    2446 compiler_options_kvs = self._compiler_options_kvs + t_compiler_options
#    2447 if self._executable is None or compiler_options_kvs:
# -> 2448   executable = UnloadedMeshExecutable.from_hlo(
#    2449       self._name, self._hlo, **self.compile_args,
#    2450       compiler_options_kvs=compiler_options_kvs)
#    2451   if not compiler_options_kvs:
#    2452     self._executable = executable
#
# File ~/.local/lib/python3.13/site-packages/jax/_src/interpreters/pxla.py:2967, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    2964       break
#    2966 util.test_event("pxla_cached_compilation")
# -> 2967 xla_executable = _cached_compilation(
#    2968     hlo, name, mesh, spmd_lowering,
#    2969     tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#    2970     allow_prop_to_outputs, tuple(host_callbacks), backend, da, pmap_nreps,
#    2971     compiler_options_kvs, pgle_profiler)
#    2973 orig_out_shardings = out_shardings
#    2975 if auto_spmd_lowering:
#
# File ~/.local/lib/python3.13/site-packages/jax/_src/interpreters/pxla.py:2758, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_kvs, pgle_profiler)
#    2750 compile_options = create_compile_options(
#    2751     computation, mesh, spmd_lowering, tuple_args, auto_spmd_lowering,
#    2752     allow_prop_to_inputs, allow_prop_to_outputs, backend,
#    2753     dev, pmap_nreps, compiler_options)
#    2755 with dispatch.log_elapsed_time(
#    2756     "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    2757     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2758   xla_executable = compiler.compile_or_get_cached(
#    2759       backend, computation, dev, compile_options, host_callbacks,
#    2760       pgle_profiler)
#    2761 return xla_executable
#
# File ~/.local/lib/python3.13/site-packages/jax/_src/compiler.py:470, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, pgle_profiler)
#     468 else:
#     469   log_persistent_cache_miss(module_name, cache_key)
# --> 470   return _compile_and_write_cache(
#     471       backend,
#     472       computation,
#     473       compile_options,
#     474       host_callbacks,
#     475       module_name,
#     476       cache_key,
#     477   )
#
# File ~/.local/lib/python3.13/site-packages/jax/_src/compiler.py:687, in _compile_and_write_cache(backend, computation, compile_options, host_callbacks, module_name, cache_key)
#     678 def _compile_and_write_cache(
#     679     backend: xc.Client,
#     680     computation: ir.Module,
#    (...)    684     cache_key: str,
#     685 ) -> xc.LoadedExecutable:
#     686   start_time = time.monotonic()
# --> 687   executable = backend_compile(
#     688       backend, computation, compile_options, host_callbacks
#     689   )
#     690   compile_time = time.monotonic() - start_time
#     691   _cache_write(
#     692       cache_key, compile_time, module_name, backend, executable, host_callbacks
#     693   )
#
# File ~/.local/lib/python3.13/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#     335   return wrapper
#
# File ~/.local/lib/python3.13/site-packages/jax/_src/compiler.py:321, in backend_compile(backend, module, options, host_callbacks)
#     315     return backend.compile(
#     316         built_c, compile_options=options, host_callbacks=host_callbacks
#     317     )
#     318   # Some backends don't have `host_callbacks` option yet
#     319   # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     320   # to take in `host_callbacks`
# --> 321   return backend.compile(built_c, compile_options=options)
#     322 except xc.XlaRuntimeError as e:
#     323   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# KeyboardInterrupt:
