# %%
import sys
sys.path.append('/project2/alvinjin_1630/results')

from Trainer import Trainer
# Out:
# /project2/alvinjin_1630

# %%
import torch, jax
print("PyTorch sees:", torch.cuda.device_count(), "GPUs,", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "none")
print("JAX sees:", jax.devices())
# Out:
# PyTorch sees: 0 GPUs, none
# JAX sees: [CpuDevice(id=0)]

# %%
trainer = Trainer(
    dataset='MNIST',
    hidden_dims=[256]*8,
    act_fn=jax.nn.relu,
    study_name='256x8_relu',
    num_epochs=50,
    batch_size=64
)

import dill
with open(f'{trainer.root}/data/data_by_class/label_0_1500.dill', 'rb') as f:
    dataset = dill.load(f)

trainer.run_ripser(dataset=dataset, dir_name='tests/test', k=3, maxdim=1, thresh=15, num_models=1)

# %%
# trainer.run_ripser_mnist(k=12, label_filter=0)

trainer = Trainer(
    dataset='MNIST',
    hidden_dims=[256]*8,
    act_fn=jax.nn.relu,
    study_name='256x8_relu',
    num_epochs=50,
    batch_size=64
)

trainer.graph_betti_numbers(
    dir_name='tests/ripser_k3/label_0',
    k=3,
    etas=[1, 2, 2.5, 6, 9, 12],
    maxdim=1
)

# betti_mat = trainer.get_betti_mat(dir_name='ripser_k3/label_0')
